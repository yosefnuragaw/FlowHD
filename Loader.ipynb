# %%
from utils.Dataset import KaraOneDataset
import numpy as np
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
import torch
from utils.func import prep_x

dataset_dir = "your_path\\KaraOne"
loader_5 = KaraOneDataset(
    dataset_dir,
    pts=("MM05",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=128,
    eeg_types=["imagined"],
    raw_only=False)

loader_8 = KaraOneDataset(
    dataset_dir,
    pts=("MM08",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)

loader_9 = KaraOneDataset(
    dataset_dir,
    pts=("MM09",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)

loader_10 = KaraOneDataset(
    dataset_dir,
    pts=("MM10",),
    start_idx=0,
    end_idx= 200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)

loader_11 = KaraOneDataset(
    dataset_dir,
    pts=("MM11",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)

loader_12 = KaraOneDataset(
    dataset_dir,
    pts=("MM12",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)

loader_15 = KaraOneDataset(
    dataset_dir,
    pts=("MM15",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)

loader_16 = KaraOneDataset(
    dataset_dir,
    pts=("MM16",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)

loader_18 = KaraOneDataset(
    dataset_dir,
    pts=("MM18",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)

loader_19 = KaraOneDataset(
    dataset_dir,
    pts=("MM19",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)

loader_20 = KaraOneDataset(
    dataset_dir,
    pts=("MM20",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)


loader_21 = KaraOneDataset(
    dataset_dir,
    pts=("MM21",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)


loader_2 = KaraOneDataset(
    dataset_dir,
    pts=("P02",),
    start_idx=0,
    end_idx=200,
    n_mel_channels=32,
    eeg_types=["imagined"],
    raw_only=False)

# %% [markdown]
# ## Process

# %%
x5,y5 = loader_5.get_data()
x8,y8 = loader_8.get_data()
x9,y9 = loader_9.get_data()
x10,y10 = loader_10.get_data()
x11,y11 = loader_11.get_data()
x12,y12 = loader_12.get_data()
x15,y15 = loader_15.get_data()
x16,y16 = loader_16.get_data()
x18,y18 = loader_18.get_data()
x19,y19 = loader_19.get_data()
x20,y20 = loader_20.get_data()
x21,y21 = loader_21.get_data()
x2,y2 = loader_2.get_data()

# %%
torch.manual_seed(42) 
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)

# Set seed for numpy
np.random.seed(42)



x_5 = prep_x(x5)
x_8 = prep_x(x8)
x_9 = prep_x(x9)
x_10 = prep_x(x10)
x_11 = prep_x(x11)
x_12 = prep_x(x12)
x_15 = prep_x(x15)
x_16 = prep_x(x16)
x_18 = prep_x(x18)
x_19 = prep_x(x19)
x_20 = prep_x(x20)
x_21 = prep_x(x21)
x_2 = prep_x(x2)

X = np.concatenate((x_5, x_8), axis=0)
X = np.concatenate((X, x_9), axis=0)
X = np.concatenate((X, x_10), axis=0)
X = np.concatenate((X, x_11), axis=0)
X = np.concatenate((X, x_12), axis=0)
X = np.concatenate((X, x_15), axis=0)
X = np.concatenate((X, x_16), axis=0)
X = np.concatenate((X, x_18), axis=0)
X = np.concatenate((X, x_19), axis=0)
X = np.concatenate((X, x_20), axis=0)
X = np.concatenate((X, x_21), axis=0)
X = np.concatenate((X, x_2), axis=0)

Y = np.hstack((y5,y8))
Y = np.hstack((Y,y9))
Y = np.hstack((Y,y10))
Y = np.hstack((Y,y11))
Y = np.hstack((Y,y12))
Y = np.hstack((Y,y15))
Y = np.hstack((Y,y16))
Y = np.hstack((Y,y18))
Y = np.hstack((Y,y19))
Y = np.hstack((Y,y20))
Y = np.hstack((Y,y21))
Y = np.hstack((Y,y2))



X = torch.tensor(X, dtype=torch.float32)
Y = torch.tensor(Y, dtype=torch.long)

cv_dataloader = DataLoader(TensorDataset(X,Y),shuffle=True)
torch.save(cv_dataloader, 'FFA_CV.pth')
